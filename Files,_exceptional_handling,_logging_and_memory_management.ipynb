# %% [markdown]
# # Files, exceptional handling, logging and memory management

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
#     - Compiled Language:
#       - Code is translated into machine code before execution using a compiler.
#       - Faster execution, but must recompile for changes.
#       - Example: C, C++, Rust, Go.
#     - Interpreted Language:
#       - Code is run line-by-line at runtime using an interpreter.
#       - Slower execution, but easy to run and test quickly.
#       - Example: Python, JavaScript, PHP.

# %% [markdown]
# 2. What is exception handling in Python?
#     - Exception handling in Python is a way to manage runtime errors using blocks like try, except, else, and finally, so the program doesn’t crash and can handle errors gracefully.

# %% [markdown]
# 3. What is the purpose of the finally block in exception handling?
#     - The finally block is used to define code that must run whether an exception occurs or not, such as closing files or releasing resources.

# %% [markdown]
# 4.  What is logging in Python?
#     - Logging in Python is the process of recording important events, errors, and debugging information while a program runs. It helps track the flow of execution and diagnose issues.

# %% [markdown]
# 5. What is the significance of the __del__ method in Python?
#     - The __del__ method is a destructor in Python. It is called automatically when an object is about to be destroyed, and is often used to release resources like files or network connections.

# %% [markdown]
# 6. What is the difference between import and from ... import in Python?
#     - import module → Imports the whole module. You must use the module name to access functions/variables.
#     - from module import name → Imports only the specific function/class/variable, so you can use it directly without prefixing the module name.

# %% [markdown]
# 7. How can you handle multiple exceptions in Python?
#     - Using multiple except blocks → one for each exception.
#     - Using a tuple of exceptions in a single except.

# %% [markdown]
# 8. What is the purpose of the with statement when handling files in Python0
#     - The with statement is used for automatic resource management. When handling files, it ensures the file is opened and automatically closed, even if an error occurs.

# %% [markdown]
# 9. What is the difference between multithreading and multiprocessing?
#     - Multithreading → Runs multiple threads within a single process. They share the same memory space. Best for I/O-bound tasks (like file handling, network requests).
#
#     - Multiprocessing → Runs multiple processes, each with its own memory. Best for CPU-bound tasks (like heavy calculations).

# %% [markdown]
# 10. What are the advantages of using logging in a program?
#     - Tracks program flow – helps understand what happened during execution.
#
#     - Error diagnosis – records exceptions and warnings for debugging.
#
#     - Permanent record – unlike print(), logs can be saved to a file.
#
#     - Different levels – allows filtering messages (DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
#     - Better than print – flexible, configurable, and suitable for production code.

# %% [markdown]
# 11.  What is memory management in Python?
#       - Memory management in Python is the process of allocating and releasing memory automatically so that programs run efficiently.

# %% [markdown]
# 12. What are the basic steps involved in exception handling in Python?
#     - The basic steps are:
#
#       1. try block → Place code that might raise an exception.
#
#       2. except block → Handle the exception if it occurs.
#
#       3. else block (optional) → Runs if no exception occurs.
#
#       4. finally block (optional) → Runs always (cleanup code).

# %% [markdown]
# 13. Why is memory management important in Python?
#     - Memory management is important in Python because:
#
#     - Prevents memory leaks – avoids unused objects taking up memory.
#
#     - Optimizes performance – efficient use of RAM makes programs run faster.
#
#     - Ensures stability – prevents crashes due to out-of-memory errors.
#
#     - Automatic cleanup – garbage collection helps developers focus on logic instead of manual memory handling.

# %% [markdown]
# 14. What is the role of try and except in exception handling?
#     - try block → Contains the code that might raise an error.
#     - except block → Defines how to handle the error if it occurs, preventing program crash.

# %% [markdown]
# 15. How does Python's garbage collection system work?
#     - Python’s garbage collection (GC) system automatically frees memory by removing objects that are no longer in use. It works mainly in two ways:
#
#       1. Reference Counting –
#
#          - Each object keeps a count of references pointing to it.
#
#           - When the count becomes 0, the object is deleted.
#
#       2. Cyclic Garbage Collector –
#
#           - Handles circular references (e.g., objects referring to each other).
#
#           - Runs periodically to detect and clean unused cycles.

# %% [markdown]
# 16. What is the purpose of the else block in exception handling?
#   - The else block in Python exception handling is used to execute code only if no exception occurs in the try block. It helps separate normal execution from exception handling, making the code cleaner and more readable.

# %% [markdown]
# 17. What are the common logging levels in Python?
#       1.  DEBUG – Detailed information, typically of interest only for diagnosing problems.
#
#       2. INFO – Confirmation that things are working as expected.
#
#       3. WARNING – An indication that something unexpected happened, or indicative of a potential problem.
#
#       4. ERROR – Due to a more serious problem, the software has not been able to perform some function.
#
#       5. CRITICAL – A very serious error, indicating that the program itself may be unable to continue running.

# %% [markdown]
# 18. What is the difference between os.fork() and multiprocessing in Python?
#     - s.fork() is low-level and Unix-only, while multiprocessing is high-level, cross-platform, and easier to use.

# %% [markdown]
# 19.  What is the importance of closing a file in Python?
#       - Frees system resources
#
#        - Ensures data is saved
#
#        - Prevents file corruption
#
#         - Allows other programs to access the file

# %% [markdown]
# 20. What is the difference between file.read() and file.readline() in Python?
#     - Difference between file.read() and file.readline() in Python:
#
#         - file.read() – Reads the entire content of the file (or specified number of characters) at once.
#
#         - file.readline() – Reads one line from the file at a time.
#
#         - Use read() for full content, readline() for line-by-line reading.

# %% [markdown]
# 21. What is the logging module in Python used for?
#       - The logging module in Python is used to record messages from a program, such as errors, warnings, or informational messages, to help debug, monitor, and track program execution.

# %% [markdown]
# 22. What is the os module in Python used for in file handling?
#     - The os module in Python is used in file handling to interact with the operating system, such as:
#
#         - Creating, removing, and renaming files or directories
#
#         - Accessing file properties (size, path, permissions)
#
#         - Navigating the file system (changing directories, listing files)
#
# - It provides system-level file operations beyond basic file read/write.

# %% [markdown]
# 23. What are the challenges associated with memory management in Python?
#     1. Memory leaks – Objects that are no longer needed may still be referenced, preventing garbage collection.
#
#     2. Fragmentation – Frequent allocation and deallocation can fragment memory.
#
#     3. Circular references – Objects referencing each other can prevent automatic garbage collection.
#
#     4. High memory usage – Large data structures can consume significant memory.
#
#     5. Performance overhead – Automatic garbage collection can sometimes slow down the program.

# %% [markdown]
# 24.  How do you raise an exception manually in Python?
#      - In Python, you can raise an exception manually using the raise statement.

# %% [markdown]
# 25. Why is it important to use multithreading in certain applications?
#     1. Improves performance – Allows multiple tasks to run concurrently, especially in I/O-bound programs.
#
#     2. Better resource utilization – Threads share the same memory space, reducing overhead.
#
#     3. Responsive programs – Keeps applications (like GUIs or servers) responsive while performing background tasks.
#
#     4. Simplifies program design – Easier to manage concurrent tasks than creating separate processes.

# %% [markdown]
# # Practical Questions

# %% [markdown]
# 1. How can you open a file for writing in Python and write a string to it?

# %% [markdown]
#  - The answer to the 1st question

# %%
import os

def write_to_file(filename, content):
    """
    Opens a file in 'write' mode ('w') and writes content to it.
    If the file exists, its content will be erased.

    Args:
        filename (str): The name of the file to write to.
        content (str): The string content to write.
    """
    try:
        with open(filename, 'w') as file_object:
            file_object.write(content)
        print(f"Successfully wrote to '{filename}' using 'w' mode.")
    except IOError as e:
        print(f"Error writing to file: {e}")

def append_to_file(filename, content):
    """
    Opens a file in 'append' mode ('a') and adds content to the end.

    Args:
        filename (str): The name of the file to append to.
        content (str): The string content to append.
    """
    try:
        with open(filename, 'a') as file_object:
            file_object.write(content)
        print(f"Successfully appended to '{filename}' using 'a' mode.")
    except IOError as e:
        print(f"Error appending to file: {e}")
my_file = "example.txt"
if os.path.exists(my_file):
    os.remove(my_file)
    print(f"Cleaned up '{my_file}' from a previous run.")

print("\n--- Step 1: Writing to a new file ('w' mode) ---")
initial_string = "Hello, this is the first line.\n"
write_to_file(my_file, initial_string)

print("\n--- Step 2: Appending more content ('a' mode) ---")
append_string = "This line is added after the first.\n"
append_to_file(my_file, append_string)

print("\n--- Step 3: Writing again to the same file ('w' mode) ---")
overwrite_string = "This is the only content now."
write_to_file(my_file, overwrite_string)
print("\n--- Verifying final content of the file ---")
with open(my_file, 'r') as file_object:
    final_content = file_object.read()
    print(final_content)
# Out:
# Cleaned up 'example.txt' from a previous run.
#
# --- Step 1: Writing to a new file ('w' mode) ---
# Successfully wrote to 'example.txt' using 'w' mode.
#
# --- Step 2: Appending more content ('a' mode) ---
# Successfully appended to 'example.txt' using 'a' mode.
#
# --- Step 3: Writing again to the same file ('w' mode) ---
# Successfully wrote to 'example.txt' using 'w' mode.
#
# --- Verifying final content of the file ---
# This is the only content now.

# %% [markdown]
# 2. Write a Python program to read the contents of a file and print each line?

# %% [markdown]
# - The answer to the 2nd question

# %%
def create_sample_file(filename):
    """Create a sample file with some text data."""
    sample_text = [
        "Hello, World!",
        "This is a sample text file.",
        "Python makes file handling easy.",
        "Have a great day!"
    ]

    with open(filename, 'w') as file:
        for line in sample_text:
            file.write(line + "\n")
    print(f"Sample file '{filename}' created successfully!\n")

def read_and_print_file(filename):
    """Read the file and print each line."""
    try:
        with open(filename, 'r') as file:
            print(f"Contents of '{filename}':\n")
            for line_number, line in enumerate(file, start=1):
                print(f"Line {line_number}: {line.strip()}")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except Exception as e:
        print(f"An error occurred: {e}")
filename = "sample.txt"
create_sample_file(filename)
read_and_print_file(filename)
# Out:
# Sample file 'sample.txt' created successfully!
#
# Contents of 'sample.txt':
#
# Line 1: Hello, World!
# Line 2: This is a sample text file.
# Line 3: Python makes file handling easy.
# Line 4: Have a great day!

# %% [markdown]
# 3. How would you handle a case where the file doesn't exist while trying to open it for reading?

# %% [markdown]
# - The answer to the 3rd question

# %%
import os

def create_sample_file(filename):
    """Create a sample file with some default text content."""
    sample_lines = [
        "Hello, World!",
        "This is a sample text file.",
        "Python makes file handling very easy.",
        "This line was automatically added to the file."
    ]
    with open(filename, 'w') as file:
        for line in sample_lines:
            file.write(line + "\n")
    print(f"Sample file '{filename}' created successfully!\n")
def read_and_print_file(filename):
    """Read a file and print each line, creating it if missing."""
    try:
        if not os.path.exists(filename):
            print(f"File '{filename}' not found. Creating a sample file...")
            create_sample_file(filename)
        with open(filename, 'r') as file:
            print(f"Contents of '{filename}':\n")
            for line_number, line in enumerate(file, start=1):
                print(f"Line {line_number}: {line.strip()}")

    except PermissionError:
        print(f"Error: You don't have permission to access '{filename}'.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
filename = "sample.txt"
read_and_print_file(filename)
# Out:
# Contents of 'sample.txt':
#
# Line 1: Hello, World!
# Line 2: This is a sample text file.
# Line 3: Python makes file handling easy.
# Line 4: Have a great day!

# %% [markdown]
# 4. Write a Python script that reads from one file and writes its content to another file?

# %% [markdown]
# - The answer to the 4th question

# %%
import os

def create_dummy_file(filename, content):
    """Creates a file with the given content for demonstration."""
    try:
        with open(filename, 'w') as f:
            f.write(content)
        print(f"Created dummy file: '{filename}'")
    except IOError as e:
        print(f"Error creating file '{filename}': {e}")

def copy_file_content(source_file, destination_file):
    """
    Reads the content from a source file and writes it to a destination file.

    Args:
        source_file (str): The name of the file to read from.
        destination_file (str): The name of the file to write to.
    """
    try:
        with open(source_file, 'r') as infile:
            content = infile.read()
        with open(destination_file, 'w') as outfile:
            outfile.write(content)

        print(f"Successfully copied content from '{source_file}' to '{destination_file}'.")
        print("Please check your file system to verify the content.")

    except FileNotFoundError:
        print(f"Error: The file '{source_file}' was not found.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
source_file = "source.txt"
destination_file = "destination.txt"
if os.path.exists(destination_file):
    os.remove(destination_file)
dummy_content = "This is the content of the source file.\n" \
                "It has multiple lines.\n" \
                "This will be copied to the destination file."
create_dummy_file(source_file, dummy_content)
copy_file_content(source_file, destination_file)
print("\n--- Verifying content of destination file ---")
if os.path.exists(destination_file):
    with open(destination_file, 'r') as f:
        print(f.read())
else:
    print(f"Error: Destination file '{destination_file}' does not exist.")
# Out:
# Created dummy file: 'source.txt'
# Successfully copied content from 'source.txt' to 'destination.txt'.
# Please check your file system to verify the content.
#
# --- Verifying content of destination file ---
# This is the content of the source file.
# It has multiple lines.
# This will be copied to the destination file.

# %% [markdown]
# 5. How would you catch and handle division by zero error in Python?

# %% [markdown]
# - The answer to the 5th question

# %%
def safe_divide(numerator, denominator):
    """
    Performs division and handles the ZeroDivisionError gracefully.

    Args:
        numerator (int or float): The number to be divided.
        denominator (int or float): The number to divide by.

    Returns:
        float or None: The result of the division, or None if an error occurred.
    """
    try:
        result = numerator / denominator
    except ZeroDivisionError:
        print("Error: Cannot divide by zero.")
        return None
    except TypeError:
        print("Error: Inputs must be numbers.")
        return None
    else:
        print(f"Division successful. Result is: {result}")
        return result
    finally:
        print("Executing 'finally' block.")
print("--- Case 1: Successful Division ---")
safe_divide(10, 2)
print("\n" + "-"*30 + "\n")

print("--- Case 2: Division by Zero Error ---")
safe_divide(5, 0)
print("\n" + "-"*30 + "\n")

print("--- Case 3: Invalid Input (TypeError) ---")
safe_divide(10, "two")
print("\n" + "-"*30 + "\n")
result_success = safe_divide(100, 4)
if result_success is not None:
    print(f"The returned value is: {result_success}")
# Out:
# --- Case 1: Successful Division ---
# Division successful. Result is: 5.0
# Executing 'finally' block.
#
# ------------------------------
#
# --- Case 2: Division by Zero Error ---
# Error: Cannot divide by zero.
# Executing 'finally' block.
#
# ------------------------------
#
# --- Case 3: Invalid Input (TypeError) ---
# Error: Inputs must be numbers.
# Executing 'finally' block.
#
# ------------------------------
#
# Division successful. Result is: 25.0
# Executing 'finally' block.
# The returned value is: 25.0

# %% [markdown]
# 6. Write a Python program that logs an error message to a log file when a division by zero exception occurs?

# %% [markdown]
# - The answer to the 6th question

# %%
import logging
import os
LOG_FILE = "application.log"
if os.path.exists(LOG_FILE):
    os.remove(LOG_FILE)
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler(LOG_FILE)
    ]
)
def divide_numbers(numerator, denominator):
    """
    Performs a division operation and handles a potential ZeroDivisionError.

    Args:
        numerator (int or float): The number to be divided.
        denominator (int or float): The number to divide by.

    Returns:
        float or None: The result of the division, or None if an error occurs.
    """
    try:
        result = numerator / denominator
        logging.info(f"Division successful: {numerator} / {denominator} = {result}")
        return result
    except ZeroDivisionError:
        logging.exception("An error occurred: Division by zero is not allowed.")
        return None
print(f"Running division operations. Check the '{LOG_FILE}' file for logs.")
print("-" * 30)
result1 = divide_numbers(10, 2)
if result1 is not None:
    print(f"Result of 10 / 2: {result1}")
print("-" * 30)
result2 = divide_numbers(5, 0)
if result2 is None:
    print(f"Result of 5 / 0: An exception was caught and logged.")
# Out:
# ERROR:root:An error occurred: Division by zero is not allowed.
# Traceback (most recent call last):
#   File "/tmp/ipython-input-3971400012.py", line 33, in divide_numbers
#     result = numerator / denominator
#              ~~~~~~~~~~^~~~~~~~~~~~~
# ZeroDivisionError: division by zero
# Running division operations. Check the 'application.log' file for logs.
# ------------------------------
# Result of 10 / 2: 5.0
# ------------------------------
# Result of 5 / 0: An exception was caught and logged.

# %% [markdown]
# 7. How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module?

# %% [markdown]
# - The answer to the 7th question

# %%
import logging
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
def log_messages_at_all_levels():
    """
    This function logs a message at each of the standard logging levels.
    """
    logging.debug("This is a DEBUG message. It's for detailed diagnostic information, "
                  "typically only of interest to developers.")

    logging.info("This is an INFO message. It indicates that something expected is happening, "
                 "like the application starting or a successful action.")

    logging.warning("This is a WARNING message. It signifies an unexpected event or problem "
                    "that doesn't prevent the software from working, like a resource "
                    "not found that is not critical.")
    try:
        non_critical_resource = None
        if not non_critical_resource:
            logging.warning("Non-critical resource not found. Functionality might be limited.")
    except Exception as e:
        logging.error("An unexpected error occurred: %s", e)
    logging.error("This is an ERROR message. It indicates a serious problem that "
                  "prevents the software from performing a specific function, but "
                  "the application itself might still be running.")
    logging.critical("This is a CRITICAL message. It indicates a very serious error "
                     "that might lead to program termination or a total system failure. "
                     "This level is used for the most severe issues.")
if __name__ == "__main__":
    log_messages_at_all_levels()
    print("\n--- Changing log level to WARNING ---")
    logging.getLogger().setLevel(logging.WARNING)
    log_messages_at_all_levels()
# Out:
# WARNING:root:This is a WARNING message. It signifies an unexpected event or problem that doesn't prevent the software from working, like a resource not found that is not critical.
# WARNING:root:Non-critical resource not found. Functionality might be limited.
# ERROR:root:This is an ERROR message. It indicates a serious problem that prevents the software from performing a specific function, but the application itself might still be running.
# CRITICAL:root:This is a CRITICAL message. It indicates a very serious error that might lead to program termination or a total system failure. This level is used for the most severe issues.
# WARNING:root:This is a WARNING message. It signifies an unexpected event or problem that doesn't prevent the software from working, like a resource not found that is not critical.
# WARNING:root:Non-critical resource not found. Functionality might be limited.
# ERROR:root:This is an ERROR message. It indicates a serious problem that prevents the software from performing a specific function, but the application itself might still be running.
# CRITICAL:root:This is a CRITICAL message. It indicates a very serious error that might lead to program termination or a total system failure. This level is used for the most severe issues.
# --- Changing log level to WARNING ---

# %% [markdown]
# 8. Write a program to handle a file opening error using exception handling?

# %% [markdown]
# - The answer to the 8th question

# %%
def read_file_content(filename):
    """
    Attempts to read content from a specified file.
    Args:
        filename (str): The name of the file to read.
    """
    try:
        with open(filename, 'r') as file_object:
            content = file_object.read()
            print(f"Successfully read from '{filename}'. Content:")
            print("---")
            print(content)
            print("---")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found. Please ensure the file exists in the correct directory.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
print("Attempting to read from 'existing_file.txt'...")
with open("existing_file.txt", "w") as f:
    f.write("This file was created successfully.")
read_file_content("existing_file.txt")
print("\nAttempting to read from 'nonexistent_file.txt'...")
read_file_content("nonexistent_file.txt")
# Out:
# Attempting to read from 'existing_file.txt'...
# Successfully read from 'existing_file.txt'. Content:
# ---
# This file was created successfully.
# ---
#
# Attempting to read from 'nonexistent_file.txt'...
# Error: The file 'nonexistent_file.txt' was not found. Please ensure the file exists in the correct directory.

# %% [markdown]
# 9.  How can you read a file line by line and store its content in a list in Python?

# %% [markdown]
# The answer to the 9th question

# %%
def read_file_to_list(filename):
    """
    Reads a file line by line, strips leading/trailing whitespace,
    and returns the content as a list of strings.

    Args:
        filename (str): The path to the file to be read.

    Returns:
        list: A list of strings, where each string is a line from the file.
    """
    lines = []
    try:
        with open(filename, 'r') as file:
            for line in file:
                lines.append(line.strip())
        print(f"Successfully read from '{filename}'.")
        return lines

    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None
if __name__ == "__main__":
    sample_filename = "sample.txt"
    try:
        with open(sample_filename, 'w') as f:
            f.write("First line of text.\n")
            f.write("Second line.\n")
            f.write("Third line with a bit of a trailing space. \n")
            f.write("Fourth line.")
        print(f"Created '{sample_filename}' for demonstration purposes.")
    except IOError as e:
        print(f"Could not create sample file: {e}")
        exit()
    print("\n--- Reading the contents of 'sample.txt' ---")
    file_content_list = read_file_to_list(sample_filename)
    if file_content_list is not None:
        print("File content as a list:")
        print(file_content_list)
    print("\n--- Attempting to read a nonexistent file ---")
    nonexistent_file_content = read_file_to_list("nonexistent_file.txt")
    if nonexistent_file_content is None:
        print("List is empty as expected due to the error.")
# Out:
# Created 'sample.txt' for demonstration purposes.
#
# --- Reading the contents of 'sample.txt' ---
# Successfully read from 'sample.txt'.
# File content as a list:
# ['First line of text.', 'Second line.', 'Third line with a bit of a trailing space.', 'Fourth line.']
#
# --- Attempting to read a nonexistent file ---
# Error: The file 'nonexistent_file.txt' was not found.
# List is empty as expected due to the error.

# %% [markdown]
# 10. How can you append data to an existing file in Python?

# %% [markdown]
# - The answer to the 10th question

# %%
def append_to_file(filename, data):
    """
    Appends a string of data to the end of a specified file.

    Args:
        filename (str): The name of the file to append to.
        data (str): The string data to write to the file.
    """
    try:
        with open(filename, 'a') as file:
            file.write(data)
            print(f"Successfully appended to '{filename}'.")

    except IOError as e:
        print(f"Error: Could not append to file '{filename}'. {e}")

def read_file_content(filename):
    """
    Reads and prints the entire content of a file.
    """
    try:
        with open(filename, 'r') as file:
            content = file.read()
            print(f"\n--- Current content of '{filename}' ---")
            print(content)
            print("--------------------------------------")
    except FileNotFoundError:
        print(f"\nError: The file '{filename}' was not found.")
    except Exception as e:
        print(f"\nAn unexpected error occurred while reading: {e}")
filename = "my_log.txt"
initial_content = "This is the first line of the log.\n"

print(f"Creating and writing initial content to '{filename}'.")
with open(filename, 'w') as f:
    f.write(initial_content)
read_file_content(filename)
new_data_to_append = "This is a new line added later.\n"
print("\nAppending new data...")
append_to_file(filename, new_data_to_append)
read_file_content(filename)
print("\nAppending another line...")
append_to_file(filename, "A third line has been added.\n")
read_file_content(filename)
# Out:
# Creating and writing initial content to 'my_log.txt'.
#
# --- Current content of 'my_log.txt' ---
# This is the first line of the log.
#
# --------------------------------------
#
# Appending new data...
# Successfully appended to 'my_log.txt'.
#
# --- Current content of 'my_log.txt' ---
# This is the first line of the log.
# This is a new line added later.
#
# --------------------------------------
#
# Appending another line...
# Successfully appended to 'my_log.txt'.
#
# --- Current content of 'my_log.txt' ---
# This is the first line of the log.
# This is a new line added later.
# A third line has been added.
#
# --------------------------------------

# %% [markdown]
# 11. Write a Python program that uses a try-except block to handle an error when attempting to access a
# dictionary key that doesn't existF?

# %% [markdown]
# - The answer to the 11th question

# %%
def get_value_from_dict(dictionary, key):
    """
    Safely retrieves a value from a dictionary using a try-except block.

    Args:
        dictionary (dict): The dictionary to search.
        key: The key to look for.

    Returns:
        The value associated with the key, or None if the key is not found.
    """
    try:
        value = dictionary[key]
        print(f"Success! The value for key '{key}' is: {value}")
        return value
    except KeyError:
        print(f"Error: The key '{key}' does not exist in the dictionary.")
        return None
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return None
user_profile = {
    'name': 'Sarpuri Yashvitha',
    'age': 22,
    'city': 'Chittoor'
}
print("Trying to access an existing key ('name')...")
get_value_from_dict(user_profile, 'name')
print("\nTrying to access a non-existing key ('email')...")
get_value_from_dict(user_profile, 'email')
print("\nTrying to access another existing key ('age')...")
get_value_from_dict(user_profile, 'age')
# Out:
# Trying to access an existing key ('name')...
# Success! The value for key 'name' is: Sarpuri Yashvitha
#
# Trying to access a non-existing key ('email')...
# Error: The key 'email' does not exist in the dictionary.
#
# Trying to access another existing key ('age')...
# Success! The value for key 'age' is: 22
# 22

# %% [markdown]
# 12.  Write a program that demonstrates using multiple except blocks to handle different types of exceptions?

# %% [markdown]
# The answer to the 12th question

# %%
def perform_division():
    """
    Prompts the user for two numbers and performs a division.
    Handles ValueError and ZeroDivisionError with specific messages.
    """
    try:
        # Prompt user for input
        print("Please enter two numbers to perform a division.")
        num1_str = input("Enter the first number: ")
        num2_str = input("Enter the second number: ")

        # Convert strings to integers. This might raise a ValueError.
        num1 = int(num1_str)
        num2 = int(num2_str)

        # Perform division. This might raise a ZeroDivisionError.
        result = num1 / num2

    except ValueError:
        # This block catches non-integer input.
        print("\nError: Invalid input. Please enter only whole numbers.")
        print("The program will now exit.")

    except ZeroDivisionError:
        # This block catches division by zero.
        print("\nError: Cannot divide by zero. Please enter a non-zero second number.")

    except Exception as e:
        # This is a general catch-all for any other unexpected errors.
        print(f"\nAn unexpected error occurred: {e}")

    else:
        # This block runs only if no exceptions were raised in the try block.
        print(f"\nSuccess! The result of {num1} / {num2} is: {result}")

    finally:
        # This block always runs, whether an exception occurred or not.
        print("\nDivision attempt complete.")

# --- Main program execution ---
if __name__ == "__main__":

    print("--- First attempt: Valid input ---")
    perform_division()

    print("\n--- Second attempt: Invalid input (ValueError) ---")
    perform_division()

    print("\n--- Third attempt: Division by zero (ZeroDivisionError) ---")
    perform_division()
# Out:
# --- First attempt: Valid input ---
# Please enter two numbers to perform a division.
# Enter the first number: 10
# Enter the second number: 2
#
# Success! The result of 10 / 2 is: 5.0
#
# Division attempt complete.
#
# --- Second attempt: Invalid input (ValueError) ---
# Please enter two numbers to perform a division.
# Enter the first number: hello
# Enter the second number:
#
# Error: Invalid input. Please enter only whole numbers.
# The program will now exit.
#
# Division attempt complete.
#
# --- Third attempt: Division by zero (ZeroDivisionError) ---
# Please enter two numbers to perform a division.
# Enter the first number: 5
# Enter the second number: 0
#
# Error: Cannot divide by zero. Please enter a non-zero second number.
#
# Division attempt complete.

# %% [markdown]
# 13. How would you check if a file exists before attempting to read it in Python?

# %% [markdown]
# The answer to the 13th question

# %%
import os
from pathlib import Path

def read_file_with_os(filename):
    """
    Checks for file existence using the os.path module and reads it if it exists.
    """
    print(f"\n--- Checking for '{filename}' using os.path.exists() ---")
    if os.path.exists(filename):
        try:
            with open(filename, 'r') as file:
                content = file.read()
                print("File found! Content:")
                print(content)
        except Exception as e:
            print(f"An error occurred while reading the file: {e}")
    else:
        print(f"Error: The file '{filename}' does not exist.")

def read_file_with_pathlib(filename):
    """
    Checks for file existence using the pathlib module and reads it if it exists.
    """
    print(f"\n--- Checking for '{filename}' using pathlib.Path.exists() ---")
    file_path = Path(filename)
    if file_path.exists():
        try:
            content = file_path.read_text()
            print("File found! Content:")
            print(content)
        except Exception as e:
            print(f"An error occurred while reading the file: {e}")
    else:
        print(f"Error: The file '{filename}' does not exist.")
if __name__ == "__main__":
    existing_filename = "data.txt"
    with open(existing_filename, "w") as f:
        f.write("Hello, World!\n")
        f.write("This is a test file.")
    non_existing_filename = "nonexistent.txt"
    read_file_with_os(existing_filename)
    read_file_with_os(non_existing_filename)
    read_file_with_pathlib(existing_filename)
    read_file_with_pathlib(non_existing_filename)
    os.remove(existing_filename)
    print("\nCleaned up the dummy file 'data.txt'.")
# Out:
# --- Checking for 'data.txt' using os.path.exists() ---
# File found! Content:
# Hello, World!
# This is a test file.
#
# --- Checking for 'nonexistent.txt' using os.path.exists() ---
# Error: The file 'nonexistent.txt' does not exist.
#
# --- Checking for 'data.txt' using pathlib.Path.exists() ---
# File found! Content:
# Hello, World!
# This is a test file.
#
# --- Checking for 'nonexistent.txt' using pathlib.Path.exists() ---
# Error: The file 'nonexistent.txt' does not exist.
#
# Cleaned up the dummy file 'data.txt'.

# %% [markdown]
# 14. Write a program that uses the logging module to log both informational and error messages?

# %% [markdown]
# - The answer to the 14th question

# %%
import logging
import random
import sys
logging.basicConfig(
    filename='app.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)

def run_application_task():
    """Simulates a task that might succeed or fail."""
    logging.info("Starting a new application task.")
    try:
        result = random.randint(1, 10)

        if result > 3:
            logging.info("Task completed successfully. Result: %d", result)
            return True
        else:
            raise ValueError("Task failed due to a simulated error.")

    except Exception as e:
        logging.error("An error occurred during the task.", exc_info=True)
        return False
if __name__ == "__main__":
    print("Running a few tasks. Check 'app.log' for details...")
    for i in range(5):
        print(f"Attempting task #{i + 1}...")
        run_application_task()
        print("-" * 20)

    print("Tasks finished. Please check 'app.log' for the full log history.")
    sys.exit(0)
# Out:
# Running a few tasks. Check 'app.log' for details...
# Attempting task #1...
# --------------------
# Attempting task #2...
# --------------------
# Attempting task #3...
# --------------------
# Attempting task #4...
# --------------------
# Attempting task #5...
# --------------------
# Tasks finished. Please check 'app.log' for the full log history.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0

# %% [markdown]
# 15. Write a Python program that prints the content of a file and handles the case when the file is empty?

# %% [markdown]
# - The answer to the 15th question

# %%
import os

def read_and_check_file(filename):
    """
    Reads a file and prints a message if it's empty.

    Args:
        filename (str): The path to the file to read.
    """
    print(f"--- Attempting to read '{filename}' ---")

    try:
        with open(filename, 'r') as file:
            content = file.read().strip()
            if not content:
                print(f"Success! The file '{filename}' exists but is empty.")
            else:
                print(f"File '{filename}' has content. Here it is:\n")
                print(content)

    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")

    except Exception as e:
        print(f"An unexpected error occurred: {e}")
if __name__ == "__main__":
    not_empty_filename = "not_empty.txt"
    with open(not_empty_filename, "w") as f:
        f.write("This file has some text.\n")
        f.write("It's not empty.")
    empty_filename = "empty.txt"
    with open(empty_filename, "w") as f:
        pass
    read_and_check_file(not_empty_filename)
    print("\n" + "="*30 + "\n")
    read_and_check_file(empty_filename)
    os.remove(not_empty_filename)
    os.remove(empty_filename)
    print("\nCleaned up the temporary files.")
# Out:
# --- Attempting to read 'not_empty.txt' ---
# File 'not_empty.txt' has content. Here it is:
#
# This file has some text.
# It's not empty.
#
# ==============================
#
# --- Attempting to read 'empty.txt' ---
# Success! The file 'empty.txt' exists but is empty.
#
# Cleaned up the temporary files.

# %% [markdown]
# 16. Demonstrate how to use memory profiling to check the memory usage of a small program?
#     - Step 1: Install memory_profiler
#         - First, install the memory_profiler package using pip: pip install memory-profiler
#     - Step 2: Create the Python Script

# %% [markdown]
# - The answer to the 16th question

# %%
from memory_profiler import profile
@profile
def create_large_list():
    """
    Creates a large list of strings to demonstrate memory usage.
    """
    print("Starting function 'create_large_list'...")
    my_list = []
    for i in range(1000000):
        my_list.append('x' * 100)
    print("List creation complete.")
    return my_list
if __name__ == '__main__':
    data = create_large_list()
    print("Program finished.")

# %% [markdown]
# Example Output:

# %%
Starting function 'create_large_list'...
Filename: memory_demo.py

Line #    Mem usage    Increment  Occurrences   Line Contents
=============================================================
     4     17.5 MiB     17.5 MiB           1   @profile
     5                                         def create_large_list():
     8     17.5 MiB      0.0 MiB           1       print("Starting function 'create_large_list'...")
    11     17.5 MiB      0.0 MiB           1       my_list = []
    14     95.0 MiB     77.5 MiB     1000000       my_list.append('x' * 100)
    17     95.0 MiB      0.0 MiB           1       print("List creation complete.")
    18     95.0 MiB      0.0 MiB           1       return my_list

Program finished.

# %% [markdown]
# 17.  Write a Python program to create and write a list of numbers to a file, one number per line?

# %% [markdown]
# - The answer to the 17th question

# %%
def write_numbers_to_file(filename, numbers):
    """
    Writes a list of numbers to a file, with each number on a new line.

    Args:
        filename (str): The name of the file to write to.
        numbers (list): A list of numbers (integers or floats).
    """
    try:
        with open(filename, 'w') as file:
            print(f"Writing numbers to '{filename}'...")
            for number in numbers:
                file.write(str(number) + '\n')
        print(f"Successfully wrote the list to '{filename}'.")
    except IOError as e:
        print(f"An I/O error occurred: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
if __name__ == "__main__":
    my_numbers = [10, 25, 30, 45, 60]
    output_filename = "numbers.txt"
    write_numbers_to_file(output_filename, my_numbers)
    print("\nVerifying the content of the file...")
    try:
        with open(output_filename, 'r') as file:
            content = file.read()
            print(content)
    except FileNotFoundError:
        print(f"Error: '{output_filename}' not found.")
# Out:
# Writing numbers to 'numbers.txt'...
# Successfully wrote the list to 'numbers.txt'.
#
# Verifying the content of the file...
# 10
# 25
# 30
# 45
# 60

# %% [markdown]
# 18.  How would you implement a basic logging setup that logs to a file with rotation after 1MB?

# %% [markdown]
# - The answer to the 18th question

# %%
import logging
import logging.handlers
import time
import random
import os

def setup_rotating_logger(log_file='app.log', max_bytes=1048576, backup_count=3):
    """
    Configures a logger with a RotatingFileHandler.

    Args:
        log_file (str): The name of the log file.
        max_bytes (int): The maximum size of the log file in bytes before rotation.
                         1 MB = 1 * 1024 * 1024 bytes.
        backup_count (int): The number of backup log files to keep.
    """
    # Create a logger instance
    logger = logging.getLogger(__name__)
    logger.setLevel(logging.INFO)

    # Create a rotating file handler
    # 'a' means append mode, so it adds to the file if it exists
    rotating_handler = logging.handlers.RotatingFileHandler(
        log_file,
        maxBytes=max_bytes,
        backupCount=backup_count,
        encoding='utf-8'
    )

    # Create a formatter for the log messages
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')

    # Add the formatter to the handler
    rotating_handler.setFormatter(formatter)

    # Add the handler to the logger
    logger.addHandler(rotating_handler)

    return logger

def generate_log_messages(logger):
    """
    Generates a continuous stream of log messages to demonstrate file rotation.
    The loop will run until the log file has been rotated at least once.
    """
    message_count = 0
    print("Generating log messages. The file will rotate after ~1MB.")

    while True:
        try:
            # Check the file size to stop after a rotation
            if os.path.exists('app.log.1'):
                print("Log rotation detected. Stopping message generation.")
                break

            # Generate a message and log it
            message = f"This is log message number {message_count}. " * random.randint(1, 5)
            logger.info(message)
            message_count += 1

            # Pause briefly to make the output easier to see
            time.sleep(0.01)

        except Exception as e:
            logger.error(f"An unexpected error occurred: {e}")
            break

# Main execution block
if __name__ == "__main__":
    # Remove old log files to start fresh
    for i in range(4):
        file_to_remove = f'app.log.{i}' if i > 0 else 'app.log'
        if os.path.exists(file_to_remove):
            os.remove(file_to_remove)

    # Set up the logger
    my_logger = setup_rotating_logger()

    # Start generating messages
    generate_log_messages(my_logger)

    print("\nLog generation complete. Check your directory for log files.")
    print("You should see 'app.log' and 'app.log.1', and potentially more.")
# Out:
# INFO:__main__:This is log message number 0.
# INFO:__main__:This is log message number 1.
# INFO:__main__:This is log message number 2. This is log message number 2.
# INFO:__main__:This is log message number 3. This is log message number 3. This is log message number 3. This is log message number 3.
# INFO:__main__:This is log message number 4. This is log message number 4. This is log message number 4. This is log message number 4.
# INFO:__main__:This is log message number 5. This is log message number 5.
# INFO:__main__:This is log message number 6. This is log message number 6. This is log message number 6. This is log message number 6.
# INFO:__main__:This is log message number 7.
# INFO:__main__:This is log message number 8. This is log message number 8. This is log message number 8. This is log message number 8.
# INFO:__main__:This is log message number 9. This is log message number 9. This is log message number 9.
# INFO:__main__:This is log message number 10.
# INFO:__main__:This is log message number 11. This is log message number 11. This is log message number 11. This is log message number 11. This is log message number 11.
# INFO:__main__:This is log message number 12. This is log message number 12. This is log message number 12. This is log message number 12. This is log message number 12.
# INFO:__main__:This is log message number 13. This is log message number 13.
# INFO:__main__:This is log message number 14. This is log message number 14. This is log message number 14. This is log message number 14.
# INFO:__main__:This is log message number 15. This is log message number 15. This is log message number 15.
# INFO:__main__:This is log message number 16.
# INFO:__main__:This is log message number 17. This is log message number 17. This is log message number 17. This is log message number 17. This is log message number 17.
# Generating log messages. The file will rotate after ~1MB.
# Streaming output truncated to the last 5000 lines.
# INFO:__main__:This is log message number 2809. This is log message number 2809. This is log message number 2809. This is log message number 2809.
# INFO:__main__:This is log message number 2810. This is log message number 2810. This is log message number 2810.
# INFO:__main__:This is log message number 2811. This is log message number 2811.
# INFO:__main__:This is log message number 2812. This is log message number 2812. This is log message number 2812.
# INFO:__main__:This is log message number 2813.
# INFO:__main__:This is log message number 2814. This is log message number 2814.
# INFO:__main__:This is log message number 2815. This is log message number 2815. This is log message number 2815. This is log message number 2815.
# INFO:__main__:This is log message number 2816. This is log message number 2816. This is log message number 2816. This is log message number 2816.
# INFO:__main__:This is log message number 2817. This is log message number 2817. This is log message number 2817. This is log message number 2817. This is log message number 2817.
# INFO:__main__:This is log message number 2818. This is log message number 2818. This is log message number 2818.
# INFO:__main__:This is log message number 2819. This is log message number 2819. This is log message number 2819. This is log message number 2819.
# INFO:__main__:This is log message number 2820. This is log message number 2820. This is log message number 2820.
# INFO:__main__:This is log message number 2821. This is log message number 2821.
# INFO:__main__:This is log message number 2822. This is log message number 2822.
# INFO:__main__:This is log message number 2823. This is log message number 2823. This is log message number 2823.
# INFO:__main__:This is log message number 2824. This is log message number 2824. This is log message number 2824. This is log message number 2824. This is log message number 2824.
# INFO:__main__:This is log message number 2825. This is log message number 2825. This is log message number 2825. This is log message number 2825.
# INFO:__main__:This is log message number 2826.
# INFO:__main__:This is log message number 2827. This is log message number 2827. This is log message number 2827.
# INFO:__main__:This is log message number 2828. This is log message number 2828. This is log message number 2828.
# INFO:__main__:This is log message number 2829. This is log message number 2829. This is log message number 2829. This is log message number 2829.
# INFO:__main__:This is log message number 2830. This is log message number 2830. This is log message number 2830.
# INFO:__main__:This is log message number 2831.
# INFO:__main__:This is log message number 2832. This is log message number 2832.
# INFO:__main__:This is log message number 2833.
# INFO:__main__:This is log message number 2834. This is log message number 2834. This is log message number 2834. This is log message number 2834. This is log message number 2834.
# INFO:__main__:This is log message number 2835. This is log message number 2835.
# INFO:__main__:This is log message number 2836. This is log message number 2836.
# INFO:__main__:This is log message number 2837. This is log message number 2837. This is log message number 2837. This is log message number 2837. This is log message number 2837.
# INFO:__main__:This is log message number 2838. This is log message number 2838.
# INFO:__main__:This is log message number 2839. This is log message number 2839. This is log message number 2839. This is log message number 2839.
# INFO:__main__:This is log message number 2840. This is log message number 2840. This is log message number 2840.
# INFO:__main__:This is log message number 2841. This is log message number 2841.
# INFO:__main__:This is log message number 2842.
# INFO:__main__:This is log message number 2843.
# INFO:__main__:This is log message number 2844. This is log message number 2844. This is log message number 2844. This is log message number 2844. This is log message number 2844.
# INFO:__main__:This is log message number 2845. This is log message number 2845. This is log message number 2845.
# INFO:__main__:This is log message number 2846. This is log message number 2846. This is log message number 2846. This is log message number 2846. This is log message number 2846.
# INFO:__main__:This is log message number 2847. This is log message number 2847. This is log message number 2847.
# INFO:__main__:This is log message number 2848.
# INFO:__main__:This is log message number 2849. This is log message number 2849. This is log message number 2849. This is log message number 2849.
# INFO:__main__:This is log message number 2850. This is log message number 2850.
# INFO:__main__:This is log message number 2851. This is log message number 2851.
# INFO:__main__:This is log message number 2852. This is log message number 2852. This is log message number 2852.
# INFO:__main__:This is log message number 2853. This is log message number 2853. This is log message number 2853. This is log message number 2853.
# INFO:__main__:This is log message number 2854. This is log message number 2854. This is log message number 2854.
# INFO:__main__:This is log message number 2855. This is log message number 2855. This is log message number 2855.
# INFO:__main__:This is log message number 2856. This is log message number 2856. This is log message number 2856. This is log message number 2856.
# INFO:__main__:This is log message number 2857. This is log message number 2857. This is log message number 2857.
# INFO:__main__:This is log message number 2858. This is log message number 2858. This is log message number 2858. This is log message number 2858.
# INFO:__main__:This is log message number 2859. This is log message number 2859. This is log message number 2859.
# INFO:__main__:This is log message number 2860. This is log message number 2860. This is log message number 2860.
# INFO:__main__:This is log message number 2861. This is log message number 2861. This is log message number 2861. This is log message number 2861.
# INFO:__main__:This is log message number 2862. This is log message number 2862. This is log message number 2862.
# INFO:__main__:This is log message number 2863. This is log message number 2863. This is log message number 2863. This is log message number 2863. This is log message number 2863.
# INFO:__main__:This is log message number 2864.
# INFO:__main__:This is log message number 2865.
# INFO:__main__:This is log message number 2866. This is log message number 2866. This is log message number 2866.
# INFO:__main__:This is log message number 2867.
# INFO:__main__:This is log message number 2868. This is log message number 2868. This is log message number 2868. This is log message number 2868. This is log message number 2868.
# INFO:__main__:This is log message number 2869.
# INFO:__main__:This is log message number 2870. This is log message number 2870. This is log message number 2870. This is log message number 2870. This is log message number 2870.
# INFO:__main__:This is log message number 2871. This is log message number 2871.
# INFO:__main__:This is log message number 2872. This is log message number 2872.
# INFO:__main__:This is log message number 2873. This is log message number 2873. This is log message number 2873.
# INFO:__main__:This is log message number 2874. This is log message number 2874. This is log message number 2874. This is log message number 2874. This is log message number 2874.
# INFO:__main__:This is log message number 2875. This is log message number 2875.
# INFO:__main__:This is log message number 2876. This is log message number 2876. This is log message number 2876.
# INFO:__main__:This is log message number 2877. This is log message number 2877. This is log message number 2877. This is log message number 2877. This is log message number 2877.
# INFO:__main__:This is log message number 2878. This is log message number 2878.
# INFO:__main__:This is log message number 2879. This is log message number 2879. This is log message number 2879. This is log message number 2879. This is log message number 2879.
# INFO:__main__:This is log message number 2880. This is log message number 2880. This is log message number 2880. This is log message number 2880. This is log message number 2880.
# INFO:__main__:This is log message number 2881. This is log message number 2881. This is log message number 2881.
# INFO:__main__:This is log message number 2882. This is log message number 2882. This is log message number 2882.
# INFO:__main__:This is log message number 2883. This is log message number 2883. This is log message number 2883. This is log message number 2883.
# INFO:__main__:This is log message number 2884. This is log message number 2884. This is log message number 2884. This is log message number 2884. This is log message number 2884.
# INFO:__main__:This is log message number 2885. This is log message number 2885. This is log message number 2885. This is log message number 2885. This is log message number 2885.
# INFO:__main__:This is log message number 2886. This is log message number 2886. This is log message number 2886. This is log message number 2886. This is log message number 2886.
# INFO:__main__:This is log message number 2887.
# INFO:__main__:This is log message number 2888. This is log message number 2888. This is log message number 2888.
# INFO:__main__:This is log message number 2889.
# INFO:__main__:This is log message number 2890. This is log message number 2890. This is log message number 2890.
# INFO:__main__:This is log message number 2891. This is log message number 2891. This is log message number 2891. This is log message number 2891.
# INFO:__main__:This is log message number 2892.
# INFO:__main__:This is log message number 2893. This is log message number 2893. This is log message number 2893. This is log message number 2893.
# INFO:__main__:This is log message number 2894. This is log message number 2894. This is log message number 2894. This is log message number 2894. This is log message number 2894.
# INFO:__main__:This is log message number 2895. This is log message number 2895. This is log message number 2895. This is log message number 2895.
# INFO:__main__:This is log message number 2896. This is log message number 2896. This is log message number 2896.
# INFO:__main__:This is log message number 2897. This is log message number 2897. This is log message number 2897. This is log message number 2897. This is log message number 2897.
# INFO:__main__:This is log message number 2898. This is log message number 2898. This is log message number 2898. This is log message number 2898.
# INFO:__main__:This is log message number 2899.
# INFO:__main__:This is log message number 2900. This is log message number 2900. This is log message number 2900. This is log message number 2900. This is log message number 2900.
# INFO:__main__:This is log message number 2901. This is log message number 2901. This is log message number 2901. This is log message number 2901. This is log message number 2901.
# INFO:__main__:This is log message number 2902.
# INFO:__main__:This is log message number 2903. This is log message number 2903. This is log message number 2903. This is log message number 2903.
# INFO:__main__:This is log message number 2904. This is log message number 2904. This is log message number 2904. This is log message number 2904.
# INFO:__main__:This is log message number 2905. This is log message number 2905. This is log message number 2905.
# INFO:__main__:This is log message number 2906. This is log message number 2906. This is log message number 2906. This is log message number 2906.
# INFO:__main__:This is log message number 2907. This is log message number 2907. This is log message number 2907. This is log message number 2907. This is log message number 2907.
# INFO:__main__:This is log message number 2908. This is log message number 2908. This is log message number 2908. This is log message number 2908.
# INFO:__main__:This is log message number 2909. This is log message number 2909. This is log message number 2909. This is log message number 2909. This is log message number 2909.
# INFO:__main__:This is log message number 2910. This is log message number 2910.
# INFO:__main__:This is log message number 2911. This is log message number 2911. This is log message number 2911. This is log message number 2911.
# INFO:__main__:This is log message number 2912. This is log message number 2912.
# INFO:__main__:This is log message number 2913. This is log message number 2913. This is log message number 2913. This is log message number 2913.
# INFO:__main__:This is log message number 2914. This is log message number 2914.
# INFO:__main__:This is log message number 2915. This is log message number 2915. This is log message number 2915.
# INFO:__main__:This is log message number 2916. This is log message number 2916. This is log message number 2916. This is log message number 2916.
# INFO:__main__:This is log message number 2917.
# INFO:__main__:This is log message number 2918. This is log message number 2918. This is log message number 2918.
# INFO:__main__:This is log message number 2919. This is log message number 2919. This is log message number 2919. This is log message number 2919.
# INFO:__main__:This is log message number 2920. This is log message number 2920. This is log message number 2920. This is log message number 2920. This is log message number 2920.
# INFO:__main__:This is log message number 2921. This is log message number 2921.
# INFO:__main__:This is log message number 2922. This is log message number 2922. This is log message number 2922.
# INFO:__main__:This is log message number 2923.
# INFO:__main__:This is log message number 2924. This is log message number 2924. This is log message number 2924.
# INFO:__main__:This is log message number 2925. This is log message number 2925.
# INFO:__main__:This is log message number 2926. This is log message number 2926. This is log message number 2926.
# INFO:__main__:This is log message number 2927. This is log message number 2927. This is log message number 2927.
# INFO:__main__:This is log message number 2928.
# INFO:__main__:This is log message number 2929. This is log message number 2929. This is log message number 2929. This is log message number 2929. This is log message number 2929.
# INFO:__main__:This is log message number 2930.
# INFO:__main__:This is log message number 2931.
# INFO:__main__:This is log message number 2932. This is log message number 2932. This is log message number 2932. This is log message number 2932.
# INFO:__main__:This is log message number 2933. This is log message number 2933.
# INFO:__main__:This is log message number 2934. This is log message number 2934.
# INFO:__main__:This is log message number 2935. This is log message number 2935. This is log message number 2935. This is log message number 2935.
# INFO:__main__:This is log message number 2936. This is log message number 2936.
# INFO:__main__:This is log message number 2937. This is log message number 2937. This is log message number 2937. This is log message number 2937. This is log message number 2937.
# INFO:__main__:This is log message number 2938. This is log message number 2938. This is log message number 2938. This is log message number 2938. This is log message number 2938.
# INFO:__main__:This is log message number 2939. This is log message number 2939.
# INFO:__main__:This is log message number 2940. This is log message number 2940.
# INFO:__main__:This is log message number 2941. This is log message number 2941.
# INFO:__main__:This is log message number 2942. This is log message number 2942. This is log message number 2942.
# INFO:__main__:This is log message number 2943. This is log message number 2943. This is log message number 2943. This is log message number 2943. This is log message number 2943.
# INFO:__main__:This is log message number 2944.
# INFO:__main__:This is log message number 2945.
# INFO:__main__:This is log message number 2946. This is log message number 2946.
# INFO:__main__:This is log message number 2947. This is log message number 2947. This is log message number 2947.
# INFO:__main__:This is log message number 2948.
# INFO:__main__:This is log message number 2949. This is log message number 2949. This is log message number 2949. This is log message number 2949. This is log message number 2949.
# INFO:__main__:This is log message number 2950.
# INFO:__main__:This is log message number 2951. This is log message number 2951. This is log message number 2951.
# INFO:__main__:This is log message number 2952. This is log message number 2952.
# INFO:__main__:This is log message number 2953. This is log message number 2953.
# INFO:__main__:This is log message number 2954. This is log message number 2954. This is log message number 2954.
# INFO:__main__:This is log message number 2955. This is log message number 2955.
# INFO:__main__:This is log message number 2956. This is log message number 2956.
# INFO:__main__:This is log message number 2957.
# INFO:__main__:This is log message number 2958.
# INFO:__main__:This is log message number 2959. This is log message number 2959.
# INFO:__main__:This is log message number 2960.
# INFO:__main__:This is log message number 2961. This is log message number 2961. This is log message number 2961. This is log message number 2961. This is log message number 2961.
# INFO:__main__:This is log message number 2962. This is log message number 2962.
# INFO:__main__:This is log message number 2963. This is log message number 2963. This is log message number 2963.
# INFO:__main__:This is log message number 2964. This is log message number 2964.
# INFO:__main__:This is log message number 2965. This is log message number 2965. This is log message number 2965. This is log message number 2965.
# INFO:__main__:This is log message number 2966. This is log message number 2966.
# INFO:__main__:This is log message number 2967. This is log message number 2967. This is log message number 2967.
# INFO:__main__:This is log message number 2968. This is log message number 2968. This is log message number 2968. This is log message number 2968. This is log message number 2968.
# INFO:__main__:This is log message number 2969. This is log message number 2969. This is log message number 2969. This is log message number 2969. This is log message number 2969.
# INFO:__main__:This is log message number 2970. This is log message number 2970. This is log message number 2970. This is log message number 2970. This is log message number 2970.
# INFO:__main__:This is log message number 2971. This is log message number 2971.
# INFO:__main__:This is log message number 2972. This is log message number 2972. This is log message number 2972. This is log message number 2972.
# INFO:__main__:This is log message number 2973. This is log message number 2973. This is log message number 2973. This is log message number 2973.
# INFO:__main__:This is log message number 2974. This is log message number 2974.
# INFO:__main__:This is log message number 2975.
# INFO:__main__:This is log message number 2976. This is log message number 2976.
# INFO:__main__:This is log message number 2977. This is log message number 2977.
# INFO:__main__:This is log message number 2978. This is log message number 2978. This is log message number 2978. This is log message number 2978.
# INFO:__main__:This is log message number 2979. This is log message number 2979. This is log message number 2979.
# INFO:__main__:This is log message number 2980.
# INFO:__main__:This is log message number 2981. This is log message number 2981. This is log message number 2981. This is log message number 2981.
# INFO:__main__:This is log message number 2982. This is log message number 2982. This is log message number 2982.
# INFO:__main__:This is log message number 2983. This is log message number 2983. This is log message number 2983. This is log message number 2983. This is log message number 2983.
# INFO:__main__:This is log message number 2984. This is log message number 2984. This is log message number 2984.
# INFO:__main__:This is log message number 2985. This is log message number 2985.
# INFO:__main__:This is log message number 2986. This is log message number 2986. This is log message number 2986. This is log message number 2986.
# INFO:__main__:This is log message number 2987. This is log message number 2987. This is log message number 2987.
# INFO:__main__:This is log message number 2988. This is log message number 2988. This is log message number 2988. This is log message number 2988.
# INFO:__main__:This is log message number 2989. This is log message number 2989.
# INFO:__main__:This is log message number 2990. This is log message number 2990. This is log message number 2990. This is log message number 2990. This is log message number 2990.
# INFO:__main__:This is log message number 2991. This is log message number 2991.
# INFO:__main__:This is log message number 2992. This is log message number 2992.
# INFO:__main__:This is log message number 2993.
# INFO:__main__:This is log message number 2994. This is log message number 2994. This is log message number 2994.
# INFO:__main__:This is log message number 2995. This is log message number 2995. This is log message number 2995. This is log message number 2995.
# INFO:__main__:This is log message number 2996. This is log message number 2996. This is log message number 2996. This is log message number 2996. This is log message number 2996.
# INFO:__main__:This is log message number 2997. This is log message number 2997. This is log message number 2997.
# INFO:__main__:This is log message number 2998. This is log message number 2998. This is log message number 2998. This is log message number 2998.
# INFO:__main__:This is log message number 2999. This is log message number 2999.
# INFO:__main__:This is log message number 3000.
# INFO:__main__:This is log message number 3001. This is log message number 3001. This is log message number 3001. This is log message number 3001.
# INFO:__main__:This is log message number 3002. This is log message number 3002. This is log message number 3002. This is log message number 3002.
# INFO:__main__:This is log message number 3003. This is log message number 3003. This is log message number 3003. This is log message number 3003. This is log message number 3003.
# INFO:__main__:This is log message number 3004.
# INFO:__main__:This is log message number 3005. This is log message number 3005.
# INFO:__main__:This is log message number 3006. This is log message number 3006. This is log message number 3006. This is log message number 3006.
# INFO:__main__:This is log message number 3007.
# INFO:__main__:This is log message number 3008. This is log message number 3008. This is log message number 3008. This is log message number 3008. This is log message number 3008.
# INFO:__main__:This is log message number 3009. This is log message number 3009. This is log message number 3009. This is log message number 3009. This is log message number 3009.
# INFO:__main__:This is log message number 3010. This is log message number 3010. This is log message number 3010. This is log message number 3010. This is log message number 3010.
# INFO:__main__:This is log message number 3011. This is log message number 3011.
# INFO:__main__:This is log message number 3012. This is log message number 3012. This is log message number 3012. This is log message number 3012.
# INFO:__main__:This is log message number 3013. This is log message number 3013. This is log message number 3013. This is log message number 3013. This is log message number 3013.
# INFO:__main__:This is log message number 3014. This is log message number 3014. This is log message number 3014. This is log message number 3014.
# INFO:__main__:This is log message number 3015.
# INFO:__main__:This is log message number 3016. This is log message number 3016. This is log message number 3016.
# INFO:__main__:This is log message number 3017.
# INFO:__main__:This is log message number 3018. This is log message number 3018. This is log message number 3018. This is log message number 3018. This is log message number 3018.
# INFO:__main__:This is log message number 3019. This is log message number 3019. This is log message number 3019.
# INFO:__main__:This is log message number 3020. This is log message number 3020. This is log message number 3020. This is log message number 3020.
# INFO:__main__:This is log message number 3021. This is log message number 3021.
# INFO:__main__:This is log message number 3022. This is log message number 3022.
# INFO:__main__:This is log message number 3023. This is log message number 3023. This is log message number 3023. This is log message number 3023. This is log message number 3023.
# INFO:__main__:This is log message number 3024. This is log message number 3024. This is log message number 3024. This is log message number 3024.
# INFO:__main__:This is log message number 3025. This is log message number 3025. This is log message number 3025. This is log message number 3025.
# INFO:__main__:This is log message number 3026. This is log message number 3026. This is log message number 3026. This is log message number 3026. This is log message number 3026.
# INFO:__main__:This is log message number 3027. This is log message number 3027. This is log message number 3027. This is log message number 3027. This is log message number 3027.
# INFO:__main__:This is log message number 3028. This is log message number 3028. This is log message number 3028.
# INFO:__main__:This is log message number 3029.
# INFO:__main__:This is log message number 3030. This is log message number 3030.
# INFO:__main__:This is log message number 3031. This is log message number 3031. This is log message number 3031.
# INFO:__main__:This is log message number 3032. This is log message number 3032. This is log message number 3032. This is log message number 3032.
# INFO:__main__:This is log message number 3033.
# INFO:__main__:This is log message number 3034. This is log message number 3034.
# INFO:__main__:This is log message number 3035. This is log message number 3035. This is log message number 3035.
# INFO:__main__:This is log message number 3036. This is log message number 3036. This is log message number 3036. This is log message number 3036. This is log message number 3036.
# INFO:__main__:This is log message number 3037. This is log message number 3037.
# INFO:__main__:This is log message number 3038. This is log message number 3038.
# INFO:__main__:This is log message number 3039. This is log message number 3039. This is log message number 3039. This is log message number 3039.
# INFO:__main__:This is log message number 3040. This is log message number 3040.
# INFO:__main__:This is log message number 3041.
# INFO:__main__:This is log message number 3042. This is log message number 3042.
# INFO:__main__:This is log message number 3043. This is log message number 3043. This is log message number 3043. This is log message number 3043.
# INFO:__main__:This is log message number 3044. This is log message number 3044. This is log message number 3044. This is log message number 3044. This is log message number 3044.
# INFO:__main__:This is log message number 3045. This is log message number 3045. This is log message number 3045. This is log message number 3045. This is log message number 3045.
# INFO:__main__:This is log message number 3046. This is log message number 3046. This is log message number 3046.
# INFO:__main__:This is log message number 3047. This is log message number 3047.
# INFO:__main__:This is log message number 3048. This is log message number 3048. This is log message number 3048. This is log message number 3048. This is log message number 3048.
# INFO:__main__:This is log message number 3049. This is log message number 3049.
# INFO:__main__:This is log message number 3050. This is log message number 3050.
# INFO:__main__:This is log message number 3051. This is log message number 3051.
# INFO:__main__:This is log message number 3052.
# INFO:__main__:This is log message number 3053.
# INFO:__main__:This is log message number 3054. This is log message number 3054. This is log message number 3054. This is log message number 3054. This is log message number 3054.
# INFO:__main__:This is log message number 3055.
# INFO:__main__:This is log message number 3056. This is log message number 3056.
# INFO:__main__:This is log message number 3057. This is log message number 3057. This is log message number 3057.
# INFO:__main__:This is log message number 3058. This is log message number 3058. This is log message number 3058.
# INFO:__main__:This is log message number 3059. This is log message number 3059. This is log message number 3059.
# INFO:__main__:This is log message number 3060. This is log message number 3060. This is log message number 3060. This is log message number 3060. This is log message number 3060.
# INFO:__main__:This is log message number 3061. This is log message number 3061. This is log message number 3061. This is log message number 3061.
# INFO:__main__:This is log message number 3062. This is log message number 3062. This is log message number 3062.
# INFO:__main__:This is log message number 3063. This is log message number 3063. This is log message number 3063. This is log message number 3063. This is log message number 3063.
# INFO:__main__:This is log message number 3064. This is log message number 3064. This is log message number 3064. This is log message number 3064. This is log message number 3064.
# INFO:__main__:This is log message number 3065. This is log message number 3065. This is log message number 3065. This is log message number 3065. This is log message number 3065.
# INFO:__main__:This is log message number 3066.
# INFO:__main__:This is log message number 3067. This is log message number 3067.
# INFO:__main__:This is log message number 3068.
# INFO:__main__:This is log message number 3069. This is log message number 3069. This is log message number 3069. This is log message number 3069. This is log message number 3069.
# INFO:__main__:This is log message number 3070.
# INFO:__main__:This is log message number 3071. This is log message number 3071.
# INFO:__main__:This is log message number 3072. This is log message number 3072. This is log message number 3072.
# INFO:__main__:This is log message number 3073.
# INFO:__main__:This is log message number 3074. This is log message number 3074. This is log message number 3074. This is log message number 3074.
# INFO:__main__:This is log message number 3075.
# INFO:__main__:This is log message number 3076.
# INFO:__main__:This is log message number 3077. This is log message number 3077.
# INFO:__main__:This is log message number 3078. This is log message number 3078. This is log message number 3078.
# INFO:__main__:This is log message number 3079. This is log message number 3079. This is log message number 3079. This is log message number 3079. This is log message number 3079.
# INFO:__main__:This is log message number 3080.
# INFO:__main__:This is log message number 3081. This is log message number 3081. This is log message number 3081. This is log message number 3081.
# INFO:__main__:This is log message number 3082.
# INFO:__main__:This is log message number 3083. This is log message number 3083. This is log message number 3083. This is log message number 3083.
# INFO:__main__:This is log message number 3084. This is log message number 3084.
# INFO:__main__:This is log message number 3085. This is log message number 3085.
# INFO:__main__:This is log message number 3086. This is log message number 3086. This is log message number 3086.
# INFO:__main__:This is log message number 3087.
# INFO:__main__:This is log message number 3088. This is log message number 3088. This is log message number 3088. This is log message number 3088.
# INFO:__main__:This is log message number 3089. This is log message number 3089. This is log message number 3089. This is log message number 3089. This is log message number 3089.
# INFO:__main__:This is log message number 3090. This is log message number 3090. This is log message number 3090. This is log message number 3090. This is log message number 3090.
# INFO:__main__:This is log message number 3091. This is log message number 3091. This is log message number 3091.
# INFO:__main__:This is log message number 3092. This is log message number 3092. This is log message number 3092. This is log message number 3092.
# INFO:__main__:This is log message number 3093. This is log message number 3093. This is log message number 3093. This is log message number 3093. This is log message number 3093.
# INFO:__main__:This is log message number 3094. This is log message number 3094. This is log message number 3094. This is log message number 3094.
# INFO:__main__:This is log message number 3095. This is log message number 3095. This is log message number 3095. This is log message number 3095. This is log message number 3095.
# INFO:__main__:This is log message number 3096. This is log message number 3096.
# INFO:__main__:This is log message number 3097.
# INFO:__main__:This is log message number 3098. This is log message number 3098.
# INFO:__main__:This is log message number 3099. This is log message number 3099. This is log message number 3099.
# INFO:__main__:This is log message number 3100. This is log message number 3100. This is log message number 3100. This is log message number 3100.
# INFO:__main__:This is log message number 3101.
# INFO:__main__:This is log message number 3102. This is log message number 3102. This is log message number 3102. This is log message number 3102.
# INFO:__main__:This is log message number 3103. This is log message number 3103. This is log message number 3103. This is log message number 3103.
# INFO:__main__:This is log message number 3104. This is log message number 3104. This is log message number 3104. This is log message number 3104.
# INFO:__main__:This is log message number 3105. This is log message number 3105. This is log message number 3105. This is log message number 3105.
# INFO:__main__:This is log message number 3106. This is log message number 3106.
# INFO:__main__:This is log message number 3107. This is log message number 3107.
# INFO:__main__:This is log message number 3108.
# INFO:__main__:This is log message number 3109. This is log message number 3109.
# INFO:__main__:This is log message number 3110. This is log message number 3110. This is log message number 3110. This is log message number 3110. This is log message number 3110.
# INFO:__main__:This is log message number 3111. This is log message number 3111. This is log message number 3111. This is log message number 3111.
# INFO:__main__:This is log message number 3112. This is log message number 3112. This is log message number 3112. This is log message number 3112.
# INFO:__main__:This is log message number 3113. This is log message number 3113. This is log message number 3113. This is log message number 3113. This is log message number 3113.
# INFO:__main__:This is log message number 3114. This is log message number 3114. This is log message number 3114. This is log message number 3114.
# INFO:__main__:This is log message number 3115. This is log message number 3115. This is log message number 3115.
# INFO:__main__:This is log message number 3116. This is log message number 3116. This is log message number 3116. This is log message number 3116.
# INFO:__main__:This is log message number 3117. This is log message number 3117. This is log message number 3117. This is log message number 3117.
# INFO:__main__:This is log message number 3118.
# INFO:__main__:This is log message number 3119. This is log message number 3119.
# INFO:__main__:This is log message number 3120. This is log message number 3120. This is log message number 3120.
# INFO:__main__:This is log message number 3121. This is log message number 3121.
# INFO:__main__:This is log message number 3122.
# INFO:__main__:This is log message number 3123. This is log message number 3123. This is log message number 3123.
# INFO:__main__:This is log message number 3124.
# INFO:__main__:This is log message number 3125.
# INFO:__main__:This is log message number 3126. This is log message number 3126.
# INFO:__main__:This is log message number 3127. This is log message number 3127. This is log message number 3127. This is log message number 3127. This is log message number 3127.
# INFO:__main__:This is log message number 3128. This is log message number 3128. This is log message number 3128. This is log message number 3128.
# INFO:__main__:This is log message number 3129. This is log message number 3129. This is log message number 3129. This is log message number 3129.
# INFO:__main__:This is log message number 3130.
# INFO:__main__:This is log message number 3131. This is log message number 3131. This is log message number 3131.
# INFO:__main__:This is log message number 3132. This is log message number 3132. This is log message number 3132.
# INFO:__main__:This is log message number 3133. This is log message number 3133. This is log message number 3133. This is log message number 3133.
# INFO:__main__:This is log message number 3134. This is log message number 3134. This is log message number 3134.
# INFO:__main__:This is log message number 3135. This is log message number 3135. This is log message number 3135. This is log message number 3135.
# INFO:__main__:This is log message number 3136. This is log message number 3136.
# INFO:__main__:This is log message number 3137. This is log message number 3137.
# INFO:__main__:This is log message number 3138. This is log message number 3138. This is log message number 3138. This is log message number 3138. This is log message number 3138.
# INFO:__main__:This is log message number 3139. This is log message number 3139. This is log message number 3139.
# INFO:__main__:This is log message number 3140. This is log message number 3140. This is log message number 3140. This is log message number 3140. This is log message number 3140.
# INFO:__main__:This is log message number 3141. This is log message number 3141. This is log message number 3141. This is log message number 3141. This is log message number 3141.
# INFO:__main__:This is log message number 3142. This is log message number 3142. This is log message number 3142. This is log message number 3142. This is log message number 3142.
# INFO:__main__:This is log message number 3143. This is log message number 3143. This is log message number 3143. This is log message number 3143. This is log message number 3143.
# INFO:__main__:This is log message number 3144.
# INFO:__main__:This is log message number 3145.
# INFO:__main__:This is log message number 3146.
# INFO:__main__:This is log message number 3147. This is log message number 3147.
# INFO:__main__:This is log message number 3148. This is log message number 3148.
# INFO:__main__:This is log message number 3149. This is log message number 3149. This is log message number 3149.
# INFO:__main__:This is log message number 3150. This is log message number 3150. This is log message number 3150. This is log message number 3150.
# INFO:__main__:This is log message number 3151. This is log message number 3151. This is log message number 3151.
# INFO:__main__:This is log message number 3152. This is log message number 3152. This is log message number 3152.
# INFO:__main__:This is log message number 3153.
# INFO:__main__:This is log message number 3154. This is log message number 3154.
# INFO:__main__:This is log message number 3155. This is log message number 3155. This is log message number 3155. This is log message number 3155.
# INFO:__main__:This is log message number 3156. This is log message number 3156. This is log message number 3156. This is log message number 3156.
# INFO:__main__:This is log message number 3157. This is log message number 3157. This is log message number 3157.
# INFO:__main__:This is log message number 3158. This is log message number 3158.
# INFO:__main__:This is log message number 3159. This is log message number 3159. This is log message number 3159. This is log message number 3159.
# INFO:__main__:This is log message number 3160. This is log message number 3160. This is log message number 3160. This is log message number 3160. This is log message number 3160.
# INFO:__main__:This is log message number 3161. This is log message number 3161. This is log message number 3161. This is log message number 3161.
# INFO:__main__:This is log message number 3162. This is log message number 3162. This is log message number 3162. This is log message number 3162. This is log message number 3162.
# INFO:__main__:This is log message number 3163. This is log message number 3163. This is log message number 3163. This is log message number 3163. This is log message number 3163.
# INFO:__main__:This is log message number 3164. This is log message number 3164. This is log message number 3164. This is log message number 3164. This is log message number 3164.
# INFO:__main__:This is log message number 3165. This is log message number 3165. This is log message number 3165. This is log message number 3165. This is log message number 3165.
# INFO:__main__:This is log message number 3166. This is log message number 3166.
# INFO:__main__:This is log message number 3167.
# INFO:__main__:This is log message number 3168. This is log message number 3168. This is log message number 3168. This is log message number 3168. This is log message number 3168.
# INFO:__main__:This is log message number 3169. This is log message number 3169.
# INFO:__main__:This is log message number 3170. This is log message number 3170. This is log message number 3170. This is log message number 3170. This is log message number 3170.
# INFO:__main__:This is log message number 3171.
# INFO:__main__:This is log message number 3172.
# INFO:__main__:This is log message number 3173. This is log message number 3173.
# INFO:__main__:This is log message number 3174. This is log message number 3174. This is log message number 3174.
# INFO:__main__:This is log message number 3175. This is log message number 3175. This is log message number 3175. This is log message number 3175.
# INFO:__main__:This is log message number 3176. This is log message number 3176. This is log message number 3176. This is log message number 3176.
# INFO:__main__:This is log message number 3177. This is log message number 3177. This is log message number 3177. This is log message number 3177. This is log message number 3177.
# INFO:__main__:This is log message number 3178. This is log message number 3178. This is log message number 3178. This is log message number 3178. This is log message number 3178.
# INFO:__main__:This is log message number 3179. This is log message number 3179. This is log message number 3179. This is log message number 3179. This is log message number 3179.
# INFO:__main__:This is log message number 3180. This is log message number 3180. This is log message number 3180. This is log message number 3180.
# INFO:__main__:This is log message number 3181.
# INFO:__main__:This is log message number 3182. This is log message number 3182. This is log message number 3182. This is log message number 3182. This is log message number 3182.
# INFO:__main__:This is log message number 3183. This is log message number 3183. This is log message number 3183. This is log message number 3183. This is log message number 3183.
# INFO:__main__:This is log message number 3184. This is log message number 3184. This is log message number 3184. This is log message number 3184. This is log message number 3184.
# INFO:__main__:This is log message number 3185.
# INFO:__main__:This is log message number 3186. This is log message number 3186.
# INFO:__main__:This is log message number 3187. This is log message number 3187.
# INFO:__main__:This is log message number 3188. This is log message number 3188.
# INFO:__main__:This is log message number 3189. This is log message number 3189. This is log message number 3189. This is log message number 3189.
# INFO:__main__:This is log message number 3190. This is log message number 3190.
# INFO:__main__:This is log message number 3191.
# INFO:__main__:This is log message number 3192. This is log message number 3192. This is log message number 3192. This is log message number 3192.
# INFO:__main__:This is log message number 3193. This is log message number 3193. This is log message number 3193. This is log message number 3193. This is log message number 3193.
# INFO:__main__:This is log message number 3194. This is log message number 3194. This is log message number 3194. This is log message number 3194.
# INFO:__main__:This is log message number 3195. This is log message number 3195. This is log message number 3195.
# INFO:__main__:This is log message number 3196. This is log message number 3196. This is log message number 3196. This is log message number 3196.
# INFO:__main__:This is log message number 3197. This is log message number 3197.
# INFO:__main__:This is log message number 3198. This is log message number 3198.
# INFO:__main__:This is log message number 3199. This is log message number 3199.
# INFO:__main__:This is log message number 3200.
# INFO:__main__:This is log message number 3201. This is log message number 3201. This is log message number 3201.
# INFO:__main__:This is log message number 3202.
# INFO:__main__:This is log message number 3203. This is log message number 3203. This is log message number 3203. This is log message number 3203. This is log message number 3203.
# INFO:__main__:This is log message number 3204. This is log message number 3204. This is log message number 3204. This is log message number 3204.
# INFO:__main__:This is log message number 3205. This is log message number 3205. This is log message number 3205.
# INFO:__main__:This is log message number 3206. This is log message number 3206. This is log message number 3206. This is log message number 3206.
# INFO:__main__:This is log message number 3207. This is log message number 3207. This is log message number 3207.
# ...
# INFO:__main__:This is log message number 7668. This is log message number 7668. This is log message number 7668.
# INFO:__main__:This is log message number 7669. This is log message number 7669. This is log message number 7669.
# INFO:__main__:This is log message number 7670. This is log message number 7670. This is log message number 7670. This is log message number 7670.
# INFO:__main__:This is log message number 7671. This is log message number 7671.
# INFO:__main__:This is log message number 7672. This is log message number 7672. This is log message number 7672. This is log message number 7672.
# INFO:__main__:This is log message number 7673.
# INFO:__main__:This is log message number 7674. This is log message number 7674. This is log message number 7674.
# INFO:__main__:This is log message number 7675. This is log message number 7675. This is log message number 7675. This is log message number 7675.
# INFO:__main__:This is log message number 7676. This is log message number 7676.
# INFO:__main__:This is log message number 7677. This is log message number 7677. This is log message number 7677. This is log message number 7677.
# INFO:__main__:This is log message number 7678.
# INFO:__main__:This is log message number 7679.
# INFO:__main__:This is log message number 7680. This is log message number 7680. This is log message number 7680. This is log message number 7680. This is log message number 7680.
# INFO:__main__:This is log message number 7681. This is log message number 7681. This is log message number 7681.
# INFO:__main__:This is log message number 7682. This is log message number 7682. This is log message number 7682.
# INFO:__main__:This is log message number 7683. This is log message number 7683.
# INFO:__main__:This is log message number 7684. This is log message number 7684. This is log message number 7684. This is log message number 7684. This is log message number 7684.
# INFO:__main__:This is log message number 7685. This is log message number 7685.
# INFO:__main__:This is log message number 7686.
# INFO:__main__:This is log message number 7687. This is log message number 7687. This is log message number 7687. This is log message number 7687. This is log message number 7687.
# INFO:__main__:This is log message number 7688. This is log message number 7688. This is log message number 7688. This is log message number 7688.
# INFO:__main__:This is log message number 7689. This is log message number 7689. This is log message number 7689. This is log message number 7689.
# INFO:__main__:This is log message number 7690.
# INFO:__main__:This is log message number 7691.
# INFO:__main__:This is log message number 7692.
# INFO:__main__:This is log message number 7693. This is log message number 7693. This is log message number 7693. This is log message number 7693. This is log message number 7693.
# INFO:__main__:This is log message number 7694.
# INFO:__main__:This is log message number 7695. This is log message number 7695. This is log message number 7695. This is log message number 7695.
# INFO:__main__:This is log message number 7696. This is log message number 7696. This is log message number 7696.
# INFO:__main__:This is log message number 7697. This is log message number 7697. This is log message number 7697. This is log message number 7697.
# INFO:__main__:This is log message number 7698. This is log message number 7698. This is log message number 7698. This is log message number 7698.
# INFO:__main__:This is log message number 7699.
# INFO:__main__:This is log message number 7700. This is log message number 7700. This is log message number 7700. This is log message number 7700.
# INFO:__main__:This is log message number 7701. This is log message number 7701.
# INFO:__main__:This is log message number 7702. This is log message number 7702. This is log message number 7702. This is log message number 7702. This is log message number 7702.
# INFO:__main__:This is log message number 7703. This is log message number 7703. This is log message number 7703.
# INFO:__main__:This is log message number 7704. This is log message number 7704. This is log message number 7704.
# INFO:__main__:This is log message number 7705. This is log message number 7705.
# INFO:__main__:This is log message number 7706.
# INFO:__main__:This is log message number 7707. This is log message number 7707. This is log message number 7707. This is log message number 7707. This is log message number 7707.
# INFO:__main__:This is log message number 7708. This is log message number 7708. This is log message number 7708.
# INFO:__main__:This is log message number 7709.
# INFO:__main__:This is log message number 7710. This is log message number 7710. This is log message number 7710. This is log message number 7710.
# INFO:__main__:This is log message number 7711. This is log message number 7711.
# INFO:__main__:This is log message number 7712. This is log message number 7712. This is log message number 7712. This is log message number 7712. This is log message number 7712.
# INFO:__main__:This is log message number 7713. This is log message number 7713. This is log message number 7713. This is log message number 7713. This is log message number 7713.
# INFO:__main__:This is log message number 7714.
# INFO:__main__:This is log message number 7715.
# INFO:__main__:This is log message number 7716.
# INFO:__main__:This is log message number 7717. This is log message number 7717. This is log message number 7717. This is log message number 7717. This is log message number 7717.
# INFO:__main__:This is log message number 7718. This is log message number 7718. This is log message number 7718. This is log message number 7718. This is log message number 7718.
# INFO:__main__:This is log message number 7719.
# INFO:__main__:This is log message number 7720.
# INFO:__main__:This is log message number 7721. This is log message number 7721. This is log message number 7721. This is log message number 7721.
# INFO:__main__:This is log message number 7722. This is log message number 7722. This is log message number 7722. This is log message number 7722.
# INFO:__main__:This is log message number 7723. This is log message number 7723. This is log message number 7723. This is log message number 7723. This is log message number 7723.
# INFO:__main__:This is log message number 7724.
# INFO:__main__:This is log message number 7725. This is log message number 7725. This is log message number 7725. This is log message number 7725.
# INFO:__main__:This is log message number 7726. This is log message number 7726. This is log message number 7726. This is log message number 7726.
# INFO:__main__:This is log message number 7727. This is log message number 7727. This is log message number 7727.
# INFO:__main__:This is log message number 7728. This is log message number 7728.
# INFO:__main__:This is log message number 7729. This is log message number 7729. This is log message number 7729.
# INFO:__main__:This is log message number 7730. This is log message number 7730. This is log message number 7730.
# INFO:__main__:This is log message number 7731. This is log message number 7731. This is log message number 7731. This is log message number 7731. This is log message number 7731.
# INFO:__main__:This is log message number 7732. This is log message number 7732.
# INFO:__main__:This is log message number 7733. This is log message number 7733. This is log message number 7733. This is log message number 7733.
# INFO:__main__:This is log message number 7734.
# INFO:__main__:This is log message number 7735. This is log message number 7735. This is log message number 7735. This is log message number 7735.
# INFO:__main__:This is log message number 7736. This is log message number 7736.
# INFO:__main__:This is log message number 7737. This is log message number 7737.
# INFO:__main__:This is log message number 7738. This is log message number 7738.
# INFO:__main__:This is log message number 7739. This is log message number 7739. This is log message number 7739.
# INFO:__main__:This is log message number 7740.
# INFO:__main__:This is log message number 7741. This is log message number 7741. This is log message number 7741.
# INFO:__main__:This is log message number 7742. This is log message number 7742. This is log message number 7742. This is log message number 7742.
# INFO:__main__:This is log message number 7743. This is log message number 7743. This is log message number 7743. This is log message number 7743.
# INFO:__main__:This is log message number 7744. This is log message number 7744. This is log message number 7744.
# INFO:__main__:This is log message number 7745.
# INFO:__main__:This is log message number 7746. This is log message number 7746.
# INFO:__main__:This is log message number 7747. This is log message number 7747.
# INFO:__main__:This is log message number 7748. This is log message number 7748. This is log message number 7748.
# INFO:__main__:This is log message number 7749. This is log message number 7749. This is log message number 7749. This is log message number 7749.
# INFO:__main__:This is log message number 7750. This is log message number 7750. This is log message number 7750. This is log message number 7750.
# INFO:__main__:This is log message number 7751. This is log message number 7751.
# INFO:__main__:This is log message number 7752. This is log message number 7752. This is log message number 7752.
# INFO:__main__:This is log message number 7753.
# INFO:__main__:This is log message number 7754. This is log message number 7754. This is log message number 7754. This is log message number 7754.
# INFO:__main__:This is log message number 7755. This is log message number 7755. This is log message number 7755. This is log message number 7755. This is log message number 7755.
# INFO:__main__:This is log message number 7756. This is log message number 7756. This is log message number 7756. This is log message number 7756. This is log message number 7756.
# INFO:__main__:This is log message number 7757. This is log message number 7757. This is log message number 7757.
# INFO:__main__:This is log message number 7758. This is log message number 7758. This is log message number 7758. This is log message number 7758. This is log message number 7758.
# INFO:__main__:This is log message number 7759. This is log message number 7759. This is log message number 7759. This is log message number 7759. This is log message number 7759.
# INFO:__main__:This is log message number 7760. This is log message number 7760.
# INFO:__main__:This is log message number 7761. This is log message number 7761. This is log message number 7761.
# INFO:__main__:This is log message number 7762. This is log message number 7762. This is log message number 7762. This is log message number 7762.
# INFO:__main__:This is log message number 7763. This is log message number 7763. This is log message number 7763. This is log message number 7763.
# INFO:__main__:This is log message number 7764.
# INFO:__main__:This is log message number 7765. This is log message number 7765. This is log message number 7765.
# INFO:__main__:This is log message number 7766. This is log message number 7766.
# INFO:__main__:This is log message number 7767. This is log message number 7767. This is log message number 7767.
# INFO:__main__:This is log message number 7768. This is log message number 7768. This is log message number 7768.
# INFO:__main__:This is log message number 7769. This is log message number 7769. This is log message number 7769. This is log message number 7769.
# INFO:__main__:This is log message number 7770. This is log message number 7770. This is log message number 7770. This is log message number 7770.
# INFO:__main__:This is log message number 7771. This is log message number 7771. This is log message number 7771. This is log message number 7771.
# INFO:__main__:This is log message number 7772. This is log message number 7772. This is log message number 7772.
# INFO:__main__:This is log message number 7773. This is log message number 7773. This is log message number 7773.
# INFO:__main__:This is log message number 7774. This is log message number 7774. This is log message number 7774.
# INFO:__main__:This is log message number 7775. This is log message number 7775.
# INFO:__main__:This is log message number 7776. This is log message number 7776. This is log message number 7776. This is log message number 7776. This is log message number 7776.
# INFO:__main__:This is log message number 7777.
# INFO:__main__:This is log message number 7778. This is log message number 7778. This is log message number 7778. This is log message number 7778. This is log message number 7778.
# INFO:__main__:This is log message number 7779. This is log message number 7779.
# INFO:__main__:This is log message number 7780. This is log message number 7780. This is log message number 7780.
# INFO:__main__:This is log message number 7781. This is log message number 7781. This is log message number 7781.
# INFO:__main__:This is log message number 7782. This is log message number 7782. This is log message number 7782.
# INFO:__main__:This is log message number 7783. This is log message number 7783.
# INFO:__main__:This is log message number 7784. This is log message number 7784.
# INFO:__main__:This is log message number 7785. This is log message number 7785. This is log message number 7785. This is log message number 7785. This is log message number 7785.
# INFO:__main__:This is log message number 7786. This is log message number 7786. This is log message number 7786.
# INFO:__main__:This is log message number 7787. This is log message number 7787. This is log message number 7787.
# INFO:__main__:This is log message number 7788.
# INFO:__main__:This is log message number 7789. This is log message number 7789. This is log message number 7789. This is log message number 7789.
# INFO:__main__:This is log message number 7790. This is log message number 7790. This is log message number 7790.
# INFO:__main__:This is log message number 7791. This is log message number 7791. This is log message number 7791. This is log message number 7791. This is log message number 7791.
# INFO:__main__:This is log message number 7792.
# INFO:__main__:This is log message number 7793. This is log message number 7793. This is log message number 7793. This is log message number 7793. This is log message number 7793.
# INFO:__main__:This is log message number 7794.
# INFO:__main__:This is log message number 7795. This is log message number 7795.
# INFO:__main__:This is log message number 7796.
# INFO:__main__:This is log message number 7797. This is log message number 7797. This is log message number 7797. This is log message number 7797. This is log message number 7797.
# INFO:__main__:This is log message number 7798. This is log message number 7798. This is log message number 7798.
# INFO:__main__:This is log message number 7799.
# INFO:__main__:This is log message number 7800.
# INFO:__main__:This is log message number 7801. This is log message number 7801. This is log message number 7801. This is log message number 7801. This is log message number 7801.
# INFO:__main__:This is log message number 7802. This is log message number 7802. This is log message number 7802.
# INFO:__main__:This is log message number 7803. This is log message number 7803. This is log message number 7803. This is log message number 7803. This is log message number 7803.
# INFO:__main__:This is log message number 7804. This is log message number 7804. This is log message number 7804.
# INFO:__main__:This is log message number 7805. This is log message number 7805. This is log message number 7805.
# INFO:__main__:This is log message number 7806.
# INFO:__main__:This is log message number 7807. This is log message number 7807.
# INFO:__main__:This is log message number 7808. This is log message number 7808.
# Log rotation detected. Stopping message generation.
#
# Log generation complete. Check your directory for log files.
# You should see 'app.log' and 'app.log.1', and potentially more.

# %% [markdown]
# 19. Write a program that handles both IndexError and KeyError using a try-except block?

# %% [markdown]
# - The answer to the 19th question

# %%
def access_data(data_list, list_index, data_dict, dict_key):
    """
    Attempts to access an item from a list and a dictionary.
    Args:
        data_list (list): A list to access.
        list_index (int): The index to try and access from the list.
        data_dict (dict): A dictionary to access.
        dict_key (any): The key to try and access from the dictionary.
    """
    try:
        list_value = data_list[list_index]
        print(f"Successfully accessed list index {list_index}: {list_value}")
        dict_value = data_dict[dict_key]
        print(f"Successfully accessed dictionary key '{dict_key}': {dict_value}")

    except IndexError:
        print(f"Caught an IndexError: The index {list_index} is out of range for the list.")

    except KeyError:
        print(f"Caught a KeyError: The key '{dict_key}' does not exist in the dictionary.")

    except Exception as e:
        print(f"An unexpected error occurred: {e}")
    finally:
        print("---")
if __name__ == "__main__":
    my_list = ['apple', 'banana', 'cherry']
    my_dict = {'name': 'Alice', 'age': 30}
    print("--- Case 1: Valid access ---")
    access_data(my_list, 1, my_dict, 'name')
    print("\n--- Case 2: Invalid list index ---")
    access_data(my_list, 5, my_dict, 'name')
    print("\n--- Case 3: Invalid dictionary key ---")
    access_data(my_list, 1, my_dict, 'city')
# Out:
# --- Case 1: Valid access ---
# Successfully accessed list index 1: banana
# Successfully accessed dictionary key 'name': Alice
# ---
#
# --- Case 2: Invalid list index ---
# Caught an IndexError: The index 5 is out of range for the list.
# ---
#
# --- Case 3: Invalid dictionary key ---
# Successfully accessed list index 1: banana
# Caught a KeyError: The key 'city' does not exist in the dictionary.
# ---

# %% [markdown]
# 20. How would you open a file and read its contents using a context manager in Python?

# %% [markdown]
# - The answer to the 20th question

# %%
def read_file_content(filename):
    """
    Reads the content of a file using a context manager.

    Args:
        filename (str): The name of the file to read from.
    """
    try:
        with open(filename, 'r') as file:
            content = file.read()
            print(f"Content of '{filename}':\n---")
            print(content)
            print("---")
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
    except IOError as e:
        print(f"An I/O error occurred: {e}")
if __name__ == "__main__":
    sample_file_name = "sample.txt"
    with open(sample_file_name, 'w') as f:
        f.write("This is the first line.\n")
        f.write("This is the second line.\n")
        f.write("And this is the final line.")
    print("Attempting to read an existing file:")
    read_file_content(sample_file_name)
    print("\nAttempting to read a non-existent file:")
    read_file_content("non_existent_file.txt")
# Out:
# Attempting to read an existing file:
# Content of 'sample.txt':
# ---
# This is the first line.
# This is the second line.
# And this is the final line.
# ---
#
# Attempting to read a non-existent file:
# Error: The file 'non_existent_file.txt' was not found.

# %% [markdown]
# 21. Write a Python program that reads a file and prints the number of occurrences of a specific word?

# %% [markdown]
# - The answer to the 21st question

# %%
import re
def count_word_occurrences(filename, target_word):
    """
    Reads a file and counts the number of occurrences of a specific word.
    The search is case-insensitive.

    Args:
        filename (str): The name of the file to read.
        target_word (str): The word to search for.

    Returns:
        int: The number of times the target word appears in the file.
        -1 if the file is not found.
    """
    try:
        with open(filename, 'r') as file:
            content = file.read()
            lowercase_content = content.lower()
            lowercase_target = target_word.lower()
            matches = re.findall(r'\b' + re.escape(lowercase_target) + r'\b', lowercase_content)
            return len(matches)
    except FileNotFoundError:
        print(f"Error: The file '{filename}' was not found.")
        return -1
    except Exception as e:
        print(f"An unexpected error occurred: {e}")
        return -1
if __name__ == "__main__":
    sample_content = """
    Python is an amazing language.
    It is a very popular language.
    Learn python today.
    PYTHON is powerful.
    """
    with open('sample.txt', 'w') as f:
        f.write(sample_content)
    word_to_find = 'python'
    count = count_word_occurrences('sample.txt', word_to_find)
    if count != -1:
        print(f"The word '{word_to_find}' appears {count} times in the file.")
# Out:
# The word 'python' appears 3 times in the file.

# %% [markdown]
# 22.  How can you check if a file is empty before attempting to read its contents?

# %% [markdown]
# - The answer to the 22nd question

# %%
import os

def is_file_empty(file_path):
    """
    Checks if a file is empty by verifying its size.

    Args:
        file_path (str): The path to the file.

    Returns:
        bool: True if the file exists and is empty (size is 0 bytes),
              False otherwise.
    """
    if not os.path.exists(file_path):
        print(f"File not found: '{file_path}'")
        return False
    return os.path.getsize(file_path) == 0
def process_file(file_path):
    """
    Simulates processing a file only if it is not empty.
    """
    if is_file_empty(file_path):
        print(f"Skipping '{file_path}' because it is empty.")
    else:
        print(f"'{file_path}' is not empty. Reading its content...")
        try:
            with open(file_path, 'r') as file:
                content = file.read().strip()
                print(f"Content:\n---\n{content}\n---")
        except Exception as e:
            print(f"An error occurred while reading the file: {e}")
if __name__ == "__main__":
    with open('full_file.txt', 'w') as f:
        f.write("This file is not empty.\n")
        f.write("It has some text inside.")
    with open('empty_file.txt', 'w') as f:
        pass
    print("--- Checking 'full_file.txt' ---")
    process_file('full_file.txt')
    print("\n--- Checking 'empty_file.txt' ---")
    process_file('empty_file.txt')
    print("\n--- Checking 'non_existent_file.txt' ---")
    process_file('non_existent_file.txt')
# Out:
# --- Checking 'full_file.txt' ---
# 'full_file.txt' is not empty. Reading its content...
# Content:
# ---
# This file is not empty.
# It has some text inside.
# ---
#
# --- Checking 'empty_file.txt' ---
# Skipping 'empty_file.txt' because it is empty.
#
# --- Checking 'non_existent_file.txt' ---
# File not found: 'non_existent_file.txt'
# 'non_existent_file.txt' is not empty. Reading its content...
# An error occurred while reading the file: [Errno 2] No such file or directory: 'non_existent_file.txt'

# %% [markdown]
# 23. Write a Python program that writes to a log file when an error occurs during file handling?

# %% [markdown]
# - The answer to the 23rd question

# %%
import datetime
import os

def log_error(error_message: str):
    """
    Appends an error message with a timestamp to an error log file.

    Args:
        error_message (str): The specific error message to log.
    """
    log_file_path = "error.log"
    timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    log_entry = f"{timestamp} - ERROR: {error_message}\n"

    try:
        with open(log_file_path, 'a') as log_file:
            log_file.write(log_entry)
        print(f"Error logged to '{log_file_path}'")
    except Exception as e:
        print(f"Failed to write to log file: {e}")

def write_to_file(file_path: str, content: str):
    """
    Writes content to a specified file and handles potential errors.

    Args:
        file_path (str): The path to the file to write to.
        content (str): The content to write into the file.
    """
    try:
        directory = os.path.dirname(file_path)
        if directory and not os.path.exists(directory):
            print(f"Creating directory: {directory}")
            os.makedirs(directory)

        with open(file_path, 'w') as file:
            file.write(content)
        print(f"Successfully wrote to '{file_path}'")

    except FileNotFoundError as e:
        error_message = f"File not found or path is invalid: {e}"
        print(error_message)
        log_error(error_message)

    except PermissionError as e:
        error_message = f"Permission denied to write to file: {e}"
        print(error_message)
        log_error(error_message)
    except IOError as e:
        error_message = f"An I/O error occurred: {e}"
        print(error_message)
        log_error(error_message)

    except Exception as e:
        error_message = f"An unexpected error occurred: {e}"
        print(error_message)
        log_error(error_message)
print("--- Attempting a successful file write ---")
write_to_file("my_document.txt", "This is some sample content.")
print("\n")
print("--- Attempting a file write with a PermissionError ---")
unwritable_path = "C:/system_file.txt" if os.name == 'nt' else "/etc/system_file.txt"
write_to_file(unwritable_path, "This should not be written.")
print("\n")
print("--- Checking the contents of the log file ---")
if os.path.exists("error.log"):
    with open("error.log", 'r') as log_file:
        log_content = log_file.read()
        print("Contents of error.log:")
        print(log_content)
else:
    print("Log file 'error.log' was not created yet.")
# Out:
# --- Attempting a successful file write ---
# Successfully wrote to 'my_document.txt'
#
#
# --- Attempting a file write with a PermissionError ---
# Successfully wrote to '/etc/system_file.txt'
#
#
# --- Checking the contents of the log file ---
# Log file 'error.log' was not created yet.
